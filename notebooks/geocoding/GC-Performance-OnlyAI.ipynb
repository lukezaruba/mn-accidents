# %% [markdown]
# # Geocoding Architecture Assessment
#
# This notebook is designed to assess the performance and accuracy of the following geocoding process.
#
# `OpenAI GPT 3.5 as Geocoder`
#
# Execution time is the sum of the run time to complete the standardization and geocoding of 100 sample records.
#
# Performance is measured by several different metrics, including the Mean, Standard Deviation, RMSE, and MAE of error in the X and Y directions (Manhattan Distance), as well as the percentile error for 75, 90, and 95% of the Euclidean Distance. The percentile error analysis produces the threshold value which signifies the distance within which the predicted coordinates are considered accurate and the percentage value which indicates the portion of points that fall within the specified error threshold (75, 90, or 95).
#
# Below are the results of the tests.

# %%
# Imports
import math
import os

import folium
import geopandas as gpd
import numpy as np
import openai
import pandas as pd
import requests

# %%
openai.api_key = os.getenv('OPENAI_KEY')

# %% [markdown]
# ### Loading Data

# %%
# Ground Truth Data
truth_df = pd.read_csv(r"../../data/other/gc_research_truth.csv")

truth_df.head()
# Out:
#    index  index2    Type       ICR              Date                District  \
# 0    558     558  Injury  22301608  08/10/2022 10:53           2300 Marshall
# 1   1288    1288   Fatal  21902377  12/03/2021 17:47      2900 Detroit Lakes
# 2    467     467  Injury  20320777  06/16/2020 14:54  3200 Thief River Falls
# 3    544     544  Injury  22406181  08/13/2022 23:49         2400 East Metro
# 4    478     478  Injury  23200293  02/01/2023 18:23            2200 Mankato
#
#                                             Location RoadCondition  \
# 0  WB Interstate 90 near Magnolia, MAGNOLIA TWP, ...           Dry
# 1  210 Highway at County Road 35, UNDERWOOD, Otte...           Dry
# 2  Westbound Hwy 2 east of Hwy 92 outside Bagley,...           Dry
# 3  NB 61 HWY to Innovation, COTTAGE GROVE, Washin...           Dry
# 4  Highway 169 milepost 23, WINNEBAGO CITY TWP, F...           Dry
#
#         NumberVehicles  GroudTruth_X  GroudTruth_Y
# 0  1 Vehicle involved.    -96.098900     43.637800
# 1            2 Vehicle    -95.874370     46.281201
# 2            2 Vehicle    -95.398111     47.521845
# 3  1 Vehicle involved.    -92.910974     44.805176
# 4  1 Vehicle involved.    -94.168037     43.810902

# %%
# Raw Data
raw_df = pd.read_csv(r"../../data/other/gc_research_truth.csv")

raw_df = raw_df.drop(['GroudTruth_X', 'GroudTruth_Y'], axis = 1)

raw_df.head()
# Out:
#    index  index2    Type       ICR              Date                District  \
# 0    558     558  Injury  22301608  08/10/2022 10:53           2300 Marshall
# 1   1288    1288   Fatal  21902377  12/03/2021 17:47      2900 Detroit Lakes
# 2    467     467  Injury  20320777  06/16/2020 14:54  3200 Thief River Falls
# 3    544     544  Injury  22406181  08/13/2022 23:49         2400 East Metro
# 4    478     478  Injury  23200293  02/01/2023 18:23            2200 Mankato
#
#                                             Location RoadCondition  \
# 0  WB Interstate 90 near Magnolia, MAGNOLIA TWP, ...           Dry
# 1  210 Highway at County Road 35, UNDERWOOD, Otte...           Dry
# 2  Westbound Hwy 2 east of Hwy 92 outside Bagley,...           Dry
# 3  NB 61 HWY to Innovation, COTTAGE GROVE, Washin...           Dry
# 4  Highway 169 milepost 23, WINNEBAGO CITY TWP, F...           Dry
#
#         NumberVehicles
# 0  1 Vehicle involved.
# 1            2 Vehicle
# 2            2 Vehicle
# 3  1 Vehicle involved.
# 4  1 Vehicle involved.

# %% [markdown]
# ### Pipeline Code

# %%
# Pipeline Code
def ai_geocode_location(df, description_series):
    df["ai_xy"] = df[description_series].apply(_gpt_chat)
    
    return df
    
def _gpt_chat(input_text):
    prompt = "Geocode the following address. Return a latitude (Y) and longitude (X) as accurately as possible. When responding, only return the output text in the following format: X, Y"
    
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": prompt},
            {"role": "user", "content": input_text},
        ],
        temperature=0.7,
        n=1,
        max_tokens=150,
        stop=None,
    )
    
    return response.choices[0].message.content.strip().split("\n")[-1]

def split_xy(df):
    df["x"] = df["ai_xy"].apply(
        lambda row: None if len(row.split(",")) < 2 else row.split(",")[0].strip()
    )

    df["y"] = df["ai_xy"].apply(
        lambda row: None if len(row.split(",")) < 2 else row.split(",")[1].strip()
    )
    
    df["x"] = pd.to_numeric(df["x"], errors="coerce")
    df["y"] = pd.to_numeric(df["y"], errors="coerce")
    
    df = df[df["x"].notna()]
    df = df[df["y"].notna()]
    
    return df

# %%
# Accuracy Assessment Code
def accuracy_assessment(df):
    x_truth=list(df["GroudTruth_X"])
    y_truth=list(df["GroudTruth_Y"])
    x_pred=list(df["x"])
    y_pred=list(df["y"])
    
    # Calculate Deltas
    delta_x = []
    delta_y = []

    for i in range(len(x_truth)):
        delta_x.append(x_truth[i] - x_pred[i])
        delta_y.append(y_truth[i] - y_pred[i])

    # All Deltas
    deltas = delta_x + delta_y

    # MAE
    abs_deltas = [abs(i) for i in deltas]
    mae = sum(abs_deltas) / len(abs_deltas)

    # RMSE
    sq_deltas = [i**2 for i in deltas]
    rmse = math.sqrt((sum(sq_deltas) / len(sq_deltas)))

    # Mean
    mean = sum(deltas) / len(deltas)

    # Standard Deviation
    stdev_diffs = []
    for i in deltas:
        stdev_diffs.append(i - mean)

    stdev_diffs_sq = [i**2 for i in stdev_diffs]

    stdev = math.sqrt((sum(stdev_diffs_sq) / len(stdev_diffs_sq)))
    
    # Percentile Errors
    pe_75_et, pe_75_pwt = _percentile_error(75, x_truth, y_truth, x_pred, y_pred)
    pe_90_et, pe_90_pwt = _percentile_error(90, x_truth, y_truth, x_pred, y_pred)
    pe_95_et, pe_95_pwt = _percentile_error(95, x_truth, y_truth, x_pred, y_pred)
    
    # Output
    print("Mean: ", mean)
    print("Standard Deviation: ", stdev)
    print("MAE: ", mae)
    print("RMSE: ", rmse)
    print("75% Percentile Error Threshold: ", pe_75_et, "75% Percentile Percentage within Threshold: ", pe_75_pwt)
    print("90% Percentile Error Threshold: ", pe_90_et, "90% Percentile Percentage within Threshold: ", pe_90_pwt)
    print("95% Percentile Error Threshold: ", pe_95_et, "95% Percentile Percentage within Threshold: ", pe_95_pwt)
    
    
def _percentile_error(percentile, x_truth, y_truth, x_pred, y_pred):
    # Calculate Euclidean Distance
    errors = np.sqrt((np.array(x_truth) - np.array(x_pred))**2 + (np.array(y_truth) - np.array(y_pred))**2)
    
    # Sort
    sorted_errors = np.sort(errors)
    index = int(np.ceil((percentile / 100) * (len(errors) + 1)))
    
    # Calculate Metrics
    error_threshold = sorted_errors[index - 1]
    num_within_threshold = np.sum(errors <= error_threshold)
    percentage_within_threshold = (num_within_threshold / len(errors)) * 100
    
    return error_threshold, percentage_within_threshold

# %% [markdown]
# ### Pipeline Execution

# %%
# TIME = 1m 11.9s
geocoded_df = ai_geocode_location(raw_df, "Location")

# %%
geocoded_df
# Out:
#     index  index2    Type       ICR              Date                District  \
# 0     558     558  Injury  22301608  08/10/2022 10:53           2300 Marshall
# 1    1288    1288   Fatal  21902377  12/03/2021 17:47      2900 Detroit Lakes
# 2     467     467  Injury  20320777  06/16/2020 14:54  3200 Thief River Falls
# 3     544     544  Injury  22406181  08/13/2022 23:49         2400 East Metro
# 4     478     478  Injury  23200293  02/01/2023 18:23            2200 Mankato
# ..    ...     ...     ...       ...               ...                     ...
# 95   1016    1016  Injury  19310932  08/10/2019 13:33           3100 Virginia
# 96   1118    1118  Injury  17311110  08/26/2017 21:08           3100 Virginia
# 97   1003    1003  Injury  19901711  08/05/2019 19:23      2900 Detroit Lakes
# 98    267     267  Injury  21300442  03/16/2021 15:20           2300 Marshall
# 99    605     605  Injury  20901063  07/13/2020 14:31      2900 Detroit Lakes
#
#                                              Location RoadCondition  \
# 0   WB Interstate 90 near Magnolia, MAGNOLIA TWP, ...           Dry
# 1   210 Highway at County Road 35, UNDERWOOD, Otte...           Dry
# 2   Westbound Hwy 2 east of Hwy 92 outside Bagley,...           Dry
# 3   NB 61 HWY to Innovation, COTTAGE GROVE, Washin...           Dry
# 4   Highway 169 milepost 23, WINNEBAGO CITY TWP, F...           Dry
# ..                                                ...           ...
# 95  Highway 2 and Highway 65  near Warba, Sago Twp...           Dry
# 96  Highway 169 at County Road 61, East of Bovey, ...           Wet
# 97  10 Hwy mp29, Lake Park Twp, Becker            ...           Dry
# 98  Hwy 60 &amp; Cottonwood CR 1, MOUNTAIN LAKE TW...           Dry
# 99  Highway 113 and County Road 38, FLOM TWP, Norm...           Dry
#
#          NumberVehicles                  ai_xy
# 0   1 Vehicle involved.  -89.011864, 42.623119
# 1             2 Vehicle      -95.8889, 46.2942
# 2             2 Vehicle      -95.4067, 47.5292
# 3   1 Vehicle involved.        123.056, 47.935
# 4   1 Vehicle involved.  43.794069, -93.783618
# ..                  ...                    ...
# 95            2 Vehicle        -93.015, 47.491
# 96  1 Vehicle involved.      -93.4167, 47.3222
# 97            2 Vehicle  -95.720156, 46.956639
# 98            3 Vehicle  -95.150272, 43.979414
# 99  1 Vehicle involved.        -96.288, 47.689
#
# [100 rows x 10 columns]

# %%
geocoded_xy_df = split_xy(geocoded_df)

# %%
geocoded_xy_df
# Out:
#     index  index2    Type       ICR              Date                District  \
# 0     558     558  Injury  22301608  08/10/2022 10:53           2300 Marshall
# 1    1288    1288   Fatal  21902377  12/03/2021 17:47      2900 Detroit Lakes
# 2     467     467  Injury  20320777  06/16/2020 14:54  3200 Thief River Falls
# 3     544     544  Injury  22406181  08/13/2022 23:49         2400 East Metro
# 4     478     478  Injury  23200293  02/01/2023 18:23            2200 Mankato
# ..    ...     ...     ...       ...               ...                     ...
# 95   1016    1016  Injury  19310932  08/10/2019 13:33           3100 Virginia
# 96   1118    1118  Injury  17311110  08/26/2017 21:08           3100 Virginia
# 97   1003    1003  Injury  19901711  08/05/2019 19:23      2900 Detroit Lakes
# 98    267     267  Injury  21300442  03/16/2021 15:20           2300 Marshall
# 99    605     605  Injury  20901063  07/13/2020 14:31      2900 Detroit Lakes
#
#                                              Location RoadCondition  \
# 0   WB Interstate 90 near Magnolia, MAGNOLIA TWP, ...           Dry
# 1   210 Highway at County Road 35, UNDERWOOD, Otte...           Dry
# 2   Westbound Hwy 2 east of Hwy 92 outside Bagley,...           Dry
# 3   NB 61 HWY to Innovation, COTTAGE GROVE, Washin...           Dry
# 4   Highway 169 milepost 23, WINNEBAGO CITY TWP, F...           Dry
# ..                                                ...           ...
# 95  Highway 2 and Highway 65  near Warba, Sago Twp...           Dry
# 96  Highway 169 at County Road 61, East of Bovey, ...           Wet
# 97  10 Hwy mp29, Lake Park Twp, Becker            ...           Dry
# 98  Hwy 60 &amp; Cottonwood CR 1, MOUNTAIN LAKE TW...           Dry
# 99  Highway 113 and County Road 38, FLOM TWP, Norm...           Dry
#
#          NumberVehicles                  ai_xy           x          y
# 0   1 Vehicle involved.  -89.011864, 42.623119  -89.011864  42.623119
# 1             2 Vehicle      -95.8889, 46.2942  -95.888900  46.294200
# 2             2 Vehicle      -95.4067, 47.5292  -95.406700  47.529200
# 3   1 Vehicle involved.        123.056, 47.935  123.056000  47.935000
# 4   1 Vehicle involved.  43.794069, -93.783618   43.794069 -93.783618
# ..                  ...                    ...         ...        ...
# 95            2 Vehicle        -93.015, 47.491  -93.015000  47.491000
# 96  1 Vehicle involved.      -93.4167, 47.3222  -93.416700  47.322200
# 97            2 Vehicle  -95.720156, 46.956639  -95.720156  46.956639
# 98            3 Vehicle  -95.150272, 43.979414  -95.150272  43.979414
# 99  1 Vehicle involved.        -96.288, 47.689  -96.288000  47.689000
#
# [97 rows x 12 columns]

# %% [markdown]
# ### Accuracy Assessment

# %%
# Results
preds = geocoded_xy_df[["ICR", "x", "y"]].copy()

truth = truth_df[["ICR", "GroudTruth_X", "GroudTruth_Y"]].copy()

# Combining Predictions with Ground Truth
accuracy_df = pd.merge(preds, truth, on=["ICR"])

# %%
# Accuracy Assessment
accuracy_assessment(accuracy_df)
# Out:
# Mean:  -2.1260849896907317
# Standard Deviation:  80.02193524186016
# MAE:  45.41581379381446
# RMSE:  80.05017399878561
# 75% Percentile Error Threshold:  195.54294760799803 75% Percentile Percentage within Threshold:  76.28865979381443
# 90% Percentile Error Threshold:  197.8630643182341 90% Percentile Percentage within Threshold:  91.75257731958763
# 95% Percentile Error Threshold:  199.1254667534816 95% Percentile Percentage within Threshold:  96.90721649484536

# %%
# Reset Indexes & Ensure Invalid Records are Dropped from Truth DF
truth = truth[truth.ICR.isin(list(preds["ICR"])) == True]

truth = truth.reset_index()
preds = preds.reset_index()

# Convert to GDFs
gdf_pred = gpd.GeoDataFrame(
            preds, geometry=gpd.points_from_xy(preds["x"], preds["y"]), crs='EPSG:4326'
        )
gdf_truth = gpd.GeoDataFrame(
            truth, geometry=gpd.points_from_xy(truth["GroudTruth_X"], truth["GroudTruth_Y"]), crs='EPSG:4326'
        )

# Create Map
error_map = folium.Map(location=[45.85, -94], tiles="Cartodb Positron", zoom_start=6.5)

# Create list of point gemoetries from GDF
pred_points = [[pt.xy[1][0], pt.xy[0][0]] for pt in gdf_pred.geometry]
truth_points = [[pt.xy[1][0], pt.xy[0][0]] for pt in gdf_truth.geometry]

# Add Markers to Map
def add_features(gdf, point_list, color):
    i = 0
    for feature in point_list:   
        error_map.add_child(
            folium.Marker(
                location = feature,
                popup = "ICR: " + str(gdf.ICR[i]),
                icon=folium.Icon(color="%s" % color, icon="exclamation-sign")
            )
        )
        i += 1
        
add_features(gdf_pred, pred_points, "blue")    
add_features(gdf_truth, truth_points, "green") 

# Visualize
error_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_743b49c10eb4d22dc63aaf7570a42351 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_743b49c10eb4d22dc63aaf7570a42351&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_743b49c10eb4d22dc63aaf7570a42351 = L.map(
#                 &quot;map_743b49c10eb4d22dc63aaf7570a42351&quot;,
#                 {
#                     center: [45.85, -94.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6.5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afdf910cb32bddac6d0a982a81b9da79 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_743b49c10eb4d22dc63aaf7570a42351);
#
#
#             var marker_3628910d7be4a73efb78cbe7961897c2 = L.marker(
#                 [42.623119, -89.011864],
#                 {}
#             ).addTo(map_743b49c10eb4d22dc63aaf7570a42351);
#
#
#             var icon_81da170552646d4e5d115480d482c65a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3628910d7be4a73efb78cbe7961897c2.setIcon(icon_81da170552646d4e5d115480d482c65a);
#
#
#         var popup_494ccab44460d24aed9e1f18377f4b72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0337d09bddeff26f5dadd25e4577c813 = $(`&lt;div id=&quot;html_0337d09bddeff26f5dadd25e4577c813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ICR: 22301608&lt;/div&gt;`)[0];
#                 popup_494ccab44460d24aed9e1f18377f4b72.setContent(html_0337d09bddeff26f5dadd25e4577c813);
#
#
#
#         marker_3628910d7be4a73efb78cbe7961897c2.bindPopup(popup_494ccab44460d24aed9e1f18377f4b72)
#         ;
#
#
#
#
#             var marker_30a776b818bc5a1a326075b76b1c3e2f = L.marker(
#                 [46.2942, -95.8889],
#                 {}
#             ).addTo(map_743b49c10eb4d22dc63aaf7570a42351);
#
#
#             var icon_d0a8676c2ff8e52f0d00fac7d69c6ac6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_30a776b818bc5a1a326075b76b1c3e2f.setIcon(icon_d0a8676c2ff8e52f0d00fac7d69c6ac6);
#
#
#         var popup_b624c752e437e34effb37d7bb94a3635 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c7fffb5f742925263e192e25ec450ce = $(`&lt;div id=&quot;html_0c7fffb5f742925263e192e25ec450ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ICR: 21902377&lt;/div&gt;`)[0];
#                 popup_b624c752e437e34effb37d7bb94a3635.setContent(html_0c7fffb5f742925263e192e25ec450ce);
#
#
#
#         marker_30a776b818bc5a1a326075b76b1c3e2f.bindPopup(popup_b624c752e437e34effb37d7bb94a3635)
#         ;
#
#
#
#
#             var marker_d1a83dda9616c1ae393e68c1355a5087 = L.marker(
#                 [47.5292, -95.4067],
#                 {}
#             ).addTo(map_743b49c10eb4d22dc63aaf7570a42351);
#
#
#             var icon_0c2bebf4a55057525fa8b220d4475568 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;exclamation-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1a83dda9616c1ae393e68c1355a5087.setIcon(icon_0c2bebf4a55057525fa8b220d4475568);
#
#
#         var popup_4b7b75edff336d0f0d5c0b95b496a776 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70deb73e1c2ac7ae8bd6345241d7bb89 = $(`&lt;div id=&quot;html_70deb73e1c2ac7ae8bd6345241d7bb89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ICR: 20320777&lt;/div&gt;`)[0];
#                 popup_4b7b75edff336d0f0d5c0b95b496a776.setContent(html_70deb73e1c2ac7ae8bd6345241d7bb89);
#
#
#
#         marker_d1a83dda9616c1ae393e68c1355a5087.bindPopup(popup_4b7b75edff336d0f0d5c0b95b496a776)
#         ;
#
#
#
#
#             var marker_66ad62bede138b428ed2e323f8e14e99 = L.marker(
#                 [47.935, 123.056],
#                 {}
#             ).addTo(map_743b49c10eb4d22dc63aaf7570a42351);
